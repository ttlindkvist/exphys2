# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.loadtxt("day3/run4/run4_01.txt", skiprows=3)

# %%
plt.plot(data[:,0], data[:,1])
plt.plot(data[:,0], data[:,2])

# %%
import sympy as sp

# %%
x = sp.symbols('x')
integrand = sp.sin(x)**2 / (2 - sp.cos(x))
sp.integrate(integrand, (x, 0, sp.pi))
# Out:
# -sqrt(3)*pi + 2*pi
